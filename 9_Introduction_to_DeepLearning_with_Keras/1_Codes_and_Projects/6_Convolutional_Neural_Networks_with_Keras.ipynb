# %% [markdown]
# # Convolutional Neural Networks with Keras

# %% [markdown]
# In this exercise, we will learn how to use the Keras library to build convolutional neural networks. We will also use the popular MNIST dataset and we will compare our results to using a conventional neural network.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build convolutional neural networks
# * Convolutional neural network with one set of convolutional and pooling layers
# * Convolutional neural network with two sets of convolutional and pooling layers

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#Import-Keras-and-Packages">Import Keras and Packages</a>
# 2. <a href="#Convolutional-Neural-Network-with-One-Set-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with One Set of Convolutional and Pooling Layers</a>
# 3. <a href="#Convolutional-Neural-Network-with-Two-Sets-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers</a>
#
# </font>
# </div>

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
## os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ## Import Keras and Packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.utils import to_categorical

# %% [markdown]
# When working with convolutional neural networks in particular, we will need additional packages.

# %%
from keras.layers import Conv2D # to add convolutional layers
from keras.layers import MaxPooling2D # to add pooling layers
from keras.layers import Flatten # to flatten data for fully connected layers

# %% [markdown]
# ## Convolutional Neural Network with One Set of Convolutional and Pooling Layers

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# #### Training Data
#
# - **X_train.shape[0]**
#   - Number of training images (e.g., 60,000)
#
# - **28 × 28**
#   - Each image is 28 pixels high and 28 pixels wide
#
# - **1**
#   - Adds a channel dimension
#   - Means grayscale image (1 color channel)
#
# - **.reshape(...)**
#   - Changes data shape from:
#     - (60,000, 28, 28)
#   - To:
#     - (60,000, 28, 28, 1)
#   - Required for CNN models (Keras expects 4D input)
#
# - **.astype('float32')**
#   - Converts pixel values from integers (0–255)
#   - To floating-point numbers
#   - Better for neural networks (faster + more stable training)
#
# #### Same Process for Test Data
#
# - **X_test.shape[0]**
#   - Number of test images (e.g., 10,000)
#
# - Same reshaping:
#   - (10,000, 28, 28) → (10,000, 28, 28, 1)
#
# - Same type conversion:
#   - int → float32

# %% [markdown]
# Let's normalize the pixel values to be between 0 and 1

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %% [markdown]
# #### What is Happening in MNIST Pixel Normalization?
# #### Pixel Values in MNIST Images
#
# Pixel values in MNIST images are originally:
#
# - Range: **0 to 255**
# - 0 = black
# - 255 = white
# - Values in between = shades of gray
# #### Why 0 to 255?
#
# Each pixel in a grayscale image is stored using **8 bits (1 byte)**.
#
# So the number of possible values is:
#
# \[
# 2^8 = 256
# \]
#
# Therefore, pixel intensity ranges from:
#
# - **0 → 255**
# #### What These Values Represent
#
# | Pixel Value | Meaning |
# |------------|--------|
# | 0 | Black |
# | 50 | Dark gray |
# | 128 | Medium gray |
# | 200 | Light gray |
# | 255 | White |

# %% [markdown]
# Next, let's convert the target variable into binary categories

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories/ classes

# %% [markdown]
# Next, let's define a function that creates our model. Let's start with one set of convolutional and pooling layers.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Finally, let's call the function to create the model, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2) # means process pictures by taking chunks of 200 images and once process all images then repeate the same porcess 9 times again 

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 9s - 31ms/step - accuracy: 0.9092 - loss: 0.3178 - val_accuracy: 0.9675 - val_loss: 0.1167
# Epoch 2/10
# 300/300 - 8s - 28ms/step - accuracy: 0.9710 - loss: 0.1015 - val_accuracy: 0.9794 - val_loss: 0.0699
# Epoch 3/10
# 300/300 - 8s - 28ms/step - accuracy: 0.9802 - loss: 0.0665 - val_accuracy: 0.9803 - val_loss: 0.0602
# Epoch 4/10
# 300/300 - 8s - 28ms/step - accuracy: 0.9852 - loss: 0.0512 - val_accuracy: 0.9849 - val_loss: 0.0508
# Epoch 5/10
# 300/300 - 13s - 42ms/step - accuracy: 0.9876 - loss: 0.0427 - val_accuracy: 0.9857 - val_loss: 0.0418
# Epoch 6/10
# 300/300 - 18s - 60ms/step - accuracy: 0.9899 - loss: 0.0344 - val_accuracy: 0.9862 - val_loss: 0.0413
# Epoch 7/10
# 300/300 - 16s - 54ms/step - accuracy: 0.9911 - loss: 0.0291 - val_accuracy: 0.9872 - val_loss: 0.0386
# Epoch 8/10
# 300/300 - 13s - 44ms/step - accuracy: 0.9930 - loss: 0.0243 - val_accuracy: 0.9882 - val_loss: 0.0395
# Epoch 9/10
# ...

# %% [markdown]
# ## Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers

# %% [markdown]
# Let's redefine our convolutional model so that it has two convolutional and pooling layers instead of just one layer of each.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Now, let's call the function to create our new convolutional neural network, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 10s - 33ms/step - accuracy: 0.8630 - loss: 0.4756 - val_accuracy: 0.9572 - val_loss: 0.1494
# Epoch 2/10
# 300/300 - 10s - 32ms/step - accuracy: 0.9612 - loss: 0.1289 - val_accuracy: 0.9711 - val_loss: 0.0959
# Epoch 3/10
# 300/300 - 10s - 34ms/step - accuracy: 0.9714 - loss: 0.0919 - val_accuracy: 0.9794 - val_loss: 0.0684
# Epoch 4/10
# 300/300 - 9s - 29ms/step - accuracy: 0.9786 - loss: 0.0713 - val_accuracy: 0.9824 - val_loss: 0.0594
# Epoch 5/10
# 300/300 - 8s - 27ms/step - accuracy: 0.9818 - loss: 0.0590 - val_accuracy: 0.9824 - val_loss: 0.0557
# Epoch 6/10
# 300/300 - 9s - 31ms/step - accuracy: 0.9842 - loss: 0.0509 - val_accuracy: 0.9858 - val_loss: 0.0441
# Epoch 7/10
# 300/300 - 9s - 30ms/step - accuracy: 0.9860 - loss: 0.0450 - val_accuracy: 0.9857 - val_loss: 0.0473
# Epoch 8/10
# 300/300 - 9s - 30ms/step - accuracy: 0.9877 - loss: 0.0399 - val_accuracy: 0.9875 - val_loss: 0.0380
# Epoch 9/10
# ...

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Let's see how batch size affects the time required and accuracy of the model training.
# For this, you can try to change batch_size to 1024 and check it's effect on accuracy

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 10s - 173ms/step - accuracy: 0.6854 - loss: 1.2137 - val_accuracy: 0.8882 - val_loss: 0.3918
# Epoch 2/10
# 59/59 - 8s - 141ms/step - accuracy: 0.9101 - loss: 0.3096 - val_accuracy: 0.9342 - val_loss: 0.2258
# Epoch 3/10
# 59/59 - 8s - 136ms/step - accuracy: 0.9411 - loss: 0.2024 - val_accuracy: 0.9568 - val_loss: 0.1551
# Epoch 4/10
# 59/59 - 9s - 146ms/step - accuracy: 0.9559 - loss: 0.1507 - val_accuracy: 0.9660 - val_loss: 0.1180
# Epoch 5/10
# 59/59 - 8s - 144ms/step - accuracy: 0.9631 - loss: 0.1240 - val_accuracy: 0.9714 - val_loss: 0.0977
# Epoch 6/10
# 59/59 - 10s - 167ms/step - accuracy: 0.9679 - loss: 0.1069 - val_accuracy: 0.9742 - val_loss: 0.0859
# Epoch 7/10
# 59/59 - 8s - 142ms/step - accuracy: 0.9713 - loss: 0.0947 - val_accuracy: 0.9760 - val_loss: 0.0796
# Epoch 8/10
# 59/59 - 9s - 149ms/step - accuracy: 0.9739 - loss: 0.0857 - val_accuracy: 0.9794 - val_loss: 0.0686
# Epoch 9/10
# ...

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
# Now, let's see how number of epochs  affect the time required and accuracy of the model training.
# For this, you can keep the batch_size=1024 and epochs=25 and check it's effect on accuracy

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 10s - 163ms/step - accuracy: 0.6135 - loss: 1.4224 - val_accuracy: 0.8709 - val_loss: 0.4588
# Epoch 2/25
# 59/59 - 9s - 157ms/step - accuracy: 0.9046 - loss: 0.3307 - val_accuracy: 0.9386 - val_loss: 0.2194
# Epoch 3/25
# 59/59 - 8s - 139ms/step - accuracy: 0.9449 - loss: 0.1910 - val_accuracy: 0.9577 - val_loss: 0.1419
# Epoch 4/25
# 59/59 - 9s - 148ms/step - accuracy: 0.9594 - loss: 0.1391 - val_accuracy: 0.9645 - val_loss: 0.1173
# Epoch 5/25
# 59/59 - 9s - 150ms/step - accuracy: 0.9669 - loss: 0.1138 - val_accuracy: 0.9705 - val_loss: 0.0923
# Epoch 6/25
# 59/59 - 9s - 152ms/step - accuracy: 0.9714 - loss: 0.0959 - val_accuracy: 0.9770 - val_loss: 0.0760
# Epoch 7/25
# 59/59 - 9s - 158ms/step - accuracy: 0.9749 - loss: 0.0839 - val_accuracy: 0.9787 - val_loss: 0.0684
# Epoch 8/25
# 59/59 - 9s - 161ms/step - accuracy: 0.9766 - loss: 0.0768 - val_accuracy: 0.9780 - val_loss: 0.0644
# Epoch 9/25
# ...
